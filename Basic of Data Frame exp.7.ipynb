# %% [markdown]
# # Creating Series

# %%
# Program for creating Series using series() method of Pandas Library

# %%
#Import Pandas library
import pandas as pd

# %%
#Creating Student Name List
Name=["amruta","punam","krishna","deep","ayush"]
Name
# Out:
# ['amruta', 'punam', 'krishna', 'deep', 'ayush']

# %%
#Creating a Series 
Roll_list=pd.Series(Name,index=[1,2,3,4,5])
print(Roll_list)
# Out:
# 1     amruta
# 2      punam
# 3    krishna
# 4       deep
# 5      ayush
# dtype: object

# %% [markdown]
# # Creating Data Frame

# %%
#Import Pandas library
import pandas as pd

# %%
#Creating Data Frame
df=pd.DataFrame([[10,12,14,16],[11,18,15,21],[12,13,14,15]],
columns= ["DAA","SQL","MLAI","SE"])

# %%
df
# Out:
#    DAA  SQL  MLAI  SE
# 0   10   12    14  16
# 1   11   18    15  21
# 2   12   13    14  15

# %%
df.shape
# Out:
# (3, 4)

# %%
df.size
# Out:
# 12

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# # Adding Record (Row) to the data frame

# %%
df2=pd.DataFrame([[5,6,7,8]],
columns= ["DAA","SQL","MLAI","SE"])

# %%
df3 = pd.concat([df, df2], ignore_index=True)

# %%
df3
# Out:
#    DAA  SQL  MLAI  SE
# 0   10   12    14  16
# 1   11   18    15  21
# 2   12   13    14  15
# 3    5    6     7   8

# %% [markdown]
# # Adding Attribute (Columns) name DM

# %%
df3["DM"]=[12,15,16,14]

# %%
df3
# Out:
#    DAA  SQL  MLAI  SE  DM
# 0   10   12    14  16  12
# 1   11   18    15  21  15
# 2   12   13    14  15  16
# 3    5    6     7   8  14

# %% [markdown]
# # Deleting Record from  df3 dataframe

# %%
df4=df3.drop(index=[1])

# %%
df4
# Out:
#    DAA  SQL  MLAI  SE  DM
# 0   10   12    14  16  12
# 2   12   13    14  15  16
# 3    5    6     7   8  14

# %% [markdown]
# # Deleting Attribute (Columns) from df3 dataframe

# %%
df5=df3.drop(columns=["DM"])

# %%
df5
# Out:
#    DAA  SQL  MLAI  SE
# 0   10   12    14  16
# 1   11   18    15  21
# 2   12   13    14  15
# 3    5    6     7   8

# %%
#Finding mean of DSS 

print("Mean of DAA:", df5["DAA"].mean())
# Out:
# Mean of DAA: 9.5

# %%
#Finding median of DSS

print("Median of DAA:", df5["DAA"].median())
# Out:
# Median of DAA: 10.5

# %%
#Finding mode of DSS

print("Mode of DAA:", df5["DAA"].mode())
# Out:
# Mode of DAA: 0     5
# 1    10
# 2    11
# 3    12
# Name: DAA, dtype: int64

# %%
#Finding max number of DSS

print("Max of DAA:", df5["DAA"].max())
# Out:
# Max of DAA: 12

# %%
#Finding Min number of DSS

print("Max of DAA:", df5["DAA"].min())
# Out:
# Max of DAA: 5
